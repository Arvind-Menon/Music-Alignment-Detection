# %% [markdown]
# # Acknowledgement
# ### This Notebook has been realised owing to the tutorial series by Valerio Velardo. The playlist can be found at https://www.youtube.com/channel/UCZPFjMe1uRSirmSpznqvJfQ/playlists under the title "Deep Learning (for Audio) with python. His tutorial involved genre-classification among 10 classes.
# I modified his work for my mood-classification among 4 classes task. However, the deep learning architecture used was not influenced by his tutorial. His main influence has been in user defined functions for saving and loading data with preprocessing the data, and ploting the history curve. Valerio has been made aware of me using his tutorial for my project through LinkedIn. He even undertook my survey and had like a post regarding my project on LinkedIn.
# The following ipynb is for the PMEmo dataset, which required an additional feature to understand the song title.

# %% [markdown]
# # Load Google Drives

# %%
## Use the account 
## Email: arvind.final.dissertation@gmail.com
## Password: final paper

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 2nd Drive if necessary

# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !sudo mkdir /content/drive1
# !google-drive-ocamlfuse /content/drive1
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.22-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %% [markdown]
# # Import Libraries and define google drive paths

# %%
import json
import os
import math
import librosa
import pandas as pd

# Input_path = '/content/drive/My Drive/DEAM'
# Output_path = "/content/drive/My Drive/DEAM JSON/"

Input_path = '/content/drive1/PMEmo in folders'
Output_path = "/content/drive/My Drive/PMEmo json/"


TRACK_LEN = 15 # measured in seconds
SAMPLE_RATE = 44100
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_LEN

# %% [markdown]
# # User defined function to store the json values

# %%
def create_json(input_loc, output_loc, coeff = 13, FFT_samples=2048, hop=512, track_pieces=5):
    """ Creates a JSON file too store the MFCC values of corresponding tracks along with the track id, label, and mapping dictionary.
        The tracks are segregating as per their emotional labels. 
        
        :param input_loc (string): dataset route
        :param output_loc (string): route to the location where the json file should be stored
        :param coeff (integer): Mel coefficients for the MFFCs
        :param FFT_samples (integer): Number of samples to apply Fast Fourier Transform(FFT)
        :param hop (integer): The number of samples by which the window slides
        :param track_pieces (integer): The number of pieces a track is divided into
        :return:
        """
    name = "Sample rate:{}, MFCC coefficient:{}, Track Duration:{}, segments: {}, FFT_samples = {}.json".format(SAMPLE_RATE, coeff, TRACK_LEN, track_pieces, FFT_samples)
    final_loc = output_loc + name
    # dictionary to store mapping, labels, and MFCCs
    data = {
        "map": [],
        "label_encode": [],
        "mfcc_values": [],
        "musicId": []
    }

    samples_per_piece = int(SAMPLES_PER_TRACK / track_pieces)
    mfcc_per_piece = math.ceil(samples_per_piece / hop)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(input_loc)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not input_loc:

            # emotion label is stored in map
            label = dirpath.split("/")[-1]
            data["map"].append(label)
            print("\nEmotion Label: {}".format(label))

            # process all audio files in genre sub-dir
            for f in filenames:

		            # audio file are invoked
                file = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file, sr=SAMPLE_RATE)
                f = int(f.split(".mp3")[0])

                # process all segments of audio file
                for k in range(track_pieces):

                    # calculate start and finish sample for current segment
                    beginning = samples_per_piece * k
                    end = beginning + samples_per_piece

                    # extract MFCC
                    MFCC = librosa.feature.mfcc(signal[beginning:end], sample_rate, n_mfcc=coeff, n_fft=FFT_samples, hop_length=hop)
                    MFCC = MFCC.T

                    # store only mfcc feature with expected number of vectors
                    if len(MFCC) == mfcc_per_piece:
                        data["mfcc_values"].append(MFCC.tolist())
                        data["label_encode"].append(i-1)
                        data["musicId"].append(int(f))
                        print("{}, segment:{}, musicId: {}, label_code: {}".format(file, k+1, int(f), i-1))

    # save MFCCs to json file
    with open(final_loc, "w") as fp:
        json.dump(data, fp)

# %% [markdown]
# # Audio --> Json file containing MFFCs and other information

# %%
create_json(Input_path, Output_path, track_pieces = 20) #PMEmo 2019
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:6, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:7, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:8, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:9, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:10, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:11, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:12, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:13, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:14, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:15, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:16, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:17, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:18, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:19, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/236.mp3, segment:20, musicId: 236, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:1, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:2, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:3, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:4, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:5, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:6, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:7, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:8, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:9, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:10, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:11, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:12, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:13, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:14, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:15, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:16, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:17, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:18, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:19, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/59.mp3, segment:20, musicId: 59, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:1, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:2, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:3, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:4, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:5, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:6, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:7, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:8, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:9, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:10, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:11, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:12, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:13, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:14, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:15, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:16, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:17, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:18, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:19, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/61.mp3, segment:20, musicId: 61, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:1, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:2, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:3, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:4, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:5, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:6, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:7, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:8, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:9, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:10, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:11, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:12, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:13, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:14, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:15, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:16, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:17, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:18, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:19, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/935.mp3, segment:20, musicId: 935, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:1, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:2, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:3, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:4, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:5, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:6, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:7, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:8, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:9, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:10, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:11, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:12, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:13, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:14, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:15, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:16, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:17, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:18, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:19, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/483.mp3, segment:20, musicId: 483, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:1, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:2, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:3, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:4, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:5, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:6, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:7, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:8, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:9, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:10, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:11, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:12, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:13, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:14, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:15, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:16, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:17, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:18, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:19, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/8.mp3, segment:20, musicId: 8, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:1, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:2, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:3, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:4, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:5, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:6, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:7, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:8, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:9, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:10, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:11, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:12, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:13, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:14, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:15, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:16, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:17, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:18, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:19, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/521.mp3, segment:20, musicId: 521, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:1, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:2, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:3, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:4, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:5, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:6, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:7, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:8, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:9, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:10, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:11, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:12, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:13, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:14, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:15, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:16, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:17, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:18, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:19, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/56.mp3, segment:20, musicId: 56, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:1, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:2, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:3, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:4, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:5, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:6, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:7, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:8, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:9, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:10, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:11, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:12, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:13, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:14, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:15, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:16, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:17, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:18, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:19, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/279.mp3, segment:20, musicId: 279, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:1, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:2, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:3, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:4, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:5, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:6, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:7, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:8, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:9, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:10, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:11, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:12, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:13, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:14, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:15, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:16, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:17, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:18, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:19, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/415.mp3, segment:20, musicId: 415, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:1, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:2, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:3, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:4, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:5, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:6, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:7, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:8, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:9, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:10, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:11, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:12, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:13, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:14, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:15, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:16, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:17, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:18, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:19, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/517.mp3, segment:20, musicId: 517, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:1, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:2, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:3, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:4, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:5, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:6, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:7, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:8, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:9, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:10, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:11, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:12, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:13, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:14, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:15, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:16, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:17, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:18, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:19, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/815.mp3, segment:20, musicId: 815, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:1, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:2, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:3, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:4, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:5, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:6, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:7, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:8, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:9, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:10, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:11, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:12, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:13, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:14, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:15, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:16, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:17, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:18, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:19, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/436.mp3, segment:20, musicId: 436, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:1, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:2, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:3, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:4, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:5, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:6, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:7, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:8, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:9, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:10, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:11, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:12, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:13, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:14, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:15, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:16, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:17, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:18, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:19, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/447.mp3, segment:20, musicId: 447, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:1, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:2, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:3, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:4, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:5, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:6, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:7, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:8, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:9, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:10, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:11, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:12, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:13, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:14, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:15, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:16, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:17, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:18, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:19, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/14.mp3, segment:20, musicId: 14, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:1, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:2, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:3, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:4, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:5, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:6, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:7, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:8, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:9, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:10, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:11, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:12, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:13, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:14, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:15, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:16, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:17, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:18, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:19, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/675.mp3, segment:20, musicId: 675, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:1, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:2, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:3, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:4, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:5, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:6, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:7, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:8, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:9, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:10, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:11, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:12, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:13, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:14, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:15, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:16, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:17, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:18, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:19, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/727.mp3, segment:20, musicId: 727, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:1, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:2, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:3, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:4, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:5, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:6, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:7, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:8, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:9, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:10, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:11, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:12, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:13, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:14, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:15, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:16, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:17, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:18, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:19, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/659.mp3, segment:20, musicId: 659, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:1, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:2, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:3, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:4, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:5, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:6, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:7, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:8, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:9, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:10, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:11, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:12, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:13, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:14, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:15, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:16, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:17, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:18, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:19, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/531.mp3, segment:20, musicId: 531, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:1, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:2, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:3, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:4, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:5, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:6, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:7, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:8, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:9, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:10, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:11, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:12, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:13, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:14, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:15, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:16, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:17, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:18, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:19, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/732.mp3, segment:20, musicId: 732, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:1, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:2, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:3, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:4, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:5, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:6, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:7, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:8, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:9, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:10, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:11, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:12, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:13, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:14, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:15, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:16, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:17, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:18, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:19, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/608.mp3, segment:20, musicId: 608, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:1, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:2, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:3, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:4, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:5, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:6, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:7, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:8, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:9, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:10, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:11, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:12, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:13, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:14, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:15, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:16, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:17, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:18, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:19, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/885.mp3, segment:20, musicId: 885, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:1, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:2, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:3, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:4, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:5, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:6, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:7, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:8, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:9, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:10, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:11, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:12, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:13, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:14, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:15, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:16, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:17, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:18, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:19, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/123.mp3, segment:20, musicId: 123, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:1, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:2, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:3, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:4, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:5, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:6, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:7, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:8, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:9, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:10, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:11, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:12, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:13, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:14, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:15, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:16, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:17, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:18, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:19, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/612.mp3, segment:20, musicId: 612, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:1, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:2, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:3, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:4, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:5, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:6, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:7, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:8, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:9, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:10, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:11, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:12, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:13, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:14, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:15, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:16, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:17, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:18, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:19, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/482.mp3, segment:20, musicId: 482, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:1, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:2, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:3, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:4, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:5, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:6, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:7, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:8, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:9, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:10, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:11, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:12, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:13, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:14, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:15, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:16, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:17, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:18, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:19, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/751.mp3, segment:20, musicId: 751, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:1, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:2, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:3, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:4, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:5, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:6, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:7, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:8, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:9, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:10, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:11, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:12, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:13, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:14, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:15, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:16, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:17, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:18, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:19, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/249.mp3, segment:20, musicId: 249, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:1, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:2, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:3, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:4, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:5, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:6, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:7, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:8, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:9, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:10, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:11, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:12, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:13, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:14, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:15, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:16, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:17, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:18, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:19, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/645.mp3, segment:20, musicId: 645, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:1, musicId: 584, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:2, musicId: 584, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:3, musicId: 584, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:4, musicId: 584, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:5, musicId: 584, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:6, musicId: 584, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:7, musicId: 584, label_code: 1
# /content/drive1/PMEmo in folders/Sad/584.mp3, segment:8, musicId: 584, label_code: 1
# ...
# /content/drive1/PMEmo in folders/Angry/629.mp3, segment:18, musicId: 629, label_code: 3
# /content/drive1/PMEmo in folders/Angry/629.mp3, segment:19, musicId: 629, label_code: 3
# /content/drive1/PMEmo in folders/Angry/629.mp3, segment:20, musicId: 629, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:1, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:2, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:3, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:4, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:5, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:6, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:7, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:8, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:9, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:10, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:11, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:12, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:13, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:14, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:15, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:16, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:17, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:18, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:19, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/564.mp3, segment:20, musicId: 564, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:1, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:2, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:3, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:4, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:5, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:6, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:7, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:8, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:9, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:10, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:11, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:12, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:13, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:14, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:15, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:16, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:17, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:18, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:19, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/407.mp3, segment:20, musicId: 407, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:1, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:2, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:3, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:4, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:5, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:6, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:7, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:8, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:9, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:10, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:11, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:12, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:13, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:14, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:15, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:16, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:17, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:18, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:19, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/71.mp3, segment:20, musicId: 71, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:1, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:2, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:3, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:4, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:5, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:6, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:7, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:8, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:9, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:10, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:11, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:12, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:13, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:14, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:15, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:16, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:17, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:18, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:19, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/671.mp3, segment:20, musicId: 671, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:1, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:2, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:3, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:4, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:5, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:6, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:7, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:8, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:9, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:10, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:11, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:12, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:13, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:14, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:15, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:16, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:17, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:18, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:19, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/848.mp3, segment:20, musicId: 848, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:1, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:2, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:3, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:4, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:5, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:6, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:7, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:8, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:9, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:10, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:11, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:12, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:13, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:14, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:15, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:16, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:17, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:18, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:19, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/410.mp3, segment:20, musicId: 410, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:1, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:2, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:3, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:4, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:5, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:6, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:7, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:8, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:9, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:10, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:11, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:12, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:13, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:14, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:15, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:16, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:17, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:18, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:19, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/857.mp3, segment:20, musicId: 857, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:1, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:2, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:3, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:4, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:5, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:6, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:7, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:8, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:9, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:10, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:11, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:12, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:13, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:14, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:15, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:16, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:17, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:18, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:19, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/820.mp3, segment:20, musicId: 820, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:1, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:2, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:3, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:4, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:5, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:6, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:7, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:8, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:9, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:10, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:11, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:12, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:13, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:14, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:15, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:16, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:17, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:18, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:19, musicId: 830, label_code: 3
# /content/drive1/PMEmo in folders/Angry/830.mp3, segment:20, musicId: 830, label_code: 3
